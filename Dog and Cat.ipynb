# %% [markdown]
# 1.Import library

# %%
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
from google.colab import drive
from tensorflow import keras

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2.Load Image

# %%
image_valid = '/content/drive/MyDrive/Dog and cat'
image_train = '/content/drive/MyDrive/train dog and cat'
image_test = '/content/drive/MyDrive/test dog and cat'

# %%
label = ['cat','dog'] # gán label

# %% [markdown]
# 3.Xử lý ảnh với ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_data_gen = ImageDataGenerator( rescale = 1/225)
valid_data_gen=ImageDataGenerator( rescale = 1/225)
train_gen = train_data_gen.flow_from_directory(image_train,target_size=(200,200),class_mode='categorical')
valid_gen = valid_data_gen.flow_from_directory(image_valid,target_size=(200,200),class_mode='categorical')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 1587 images belonging to 2 classes.

# %%
print(train_gen)

# %% [markdown]
# 4.Xây dựng mô hình

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,Conv2D , MaxPooling2D,Flatten
model = tf.keras.models.Sequential()
#Lớp CNN1
model.add(Conv2D(16,(3,3), activation='relu',input_shape=(200,200,3)))
model.add(MaxPooling2D(2,2))
#Lớp CNN2
model.add(Conv2D(4,(3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten()) #chuyển dữ liệu đầu ra của CNN từ mảng 2 chiều về 1 chiều
model.add(Dense(512,activation=tf.nn.relu)) # tầng ẩn
model.add(Dense(2,activation=tf.nn.softmax)) # tầng output

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=['acc'])

# %%
EPOCHS=10
history=model.fit(train_gen,steps_per_epoch=2,epochs=EPOCHS,verbose=1,validation_data = valid_gen,validation_steps=2)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 83s 72s/step - loss: 3.4226 - acc: 0.4375 - val_loss: 0.9763 - val_acc: 0.5312
# Epoch 2/10
# 2/2 [==============================] - 37s 32s/step - loss: 1.2617 - acc: 0.5156 - val_loss: 1.2803 - val_acc: 0.5625
# Epoch 3/10
# 2/2 [==============================] - 33s 28s/step - loss: 1.3606 - acc: 0.5156 - val_loss: 0.7690 - val_acc: 0.5781
# Epoch 4/10
# 2/2 [==============================] - 36s 29s/step - loss: 0.9639 - acc: 0.3594 - val_loss: 0.7170 - val_acc: 0.4531
# Epoch 5/10
# 2/2 [==============================] - 32s 28s/step - loss: 0.6952 - acc: 0.4844 - val_loss: 0.6928 - val_acc: 0.4844
# Epoch 6/10
# 2/2 [==============================] - 28s 25s/step - loss: 0.6919 - acc: 0.4688 - val_loss: 0.6945 - val_acc: 0.4688
# Epoch 7/10
# 2/2 [==============================] - 33s 28s/step - loss: 0.6927 - acc: 0.5312 - val_loss: 0.6934 - val_acc: 0.4531
# Epoch 8/10
# ...
