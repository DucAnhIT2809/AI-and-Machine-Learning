# %%
import pandas as pd
import numpy as np
import math
import matplotlib as plt
import csv
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import statsmodels.api as sm
import seaborn as sn

# %%
# !git clone https://github.com/kohi2112002/WineQuality.git
# Out:
# Cloning into 'WineQuality'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 62 (delta 30), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (62/62), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_red = pd.read_csv('/content/WineQuality/winequality-red.csv')
df_white = pd.read_csv('/content/WineQuality/winequality-white.csv')

# %%
print(df_red.shape)
print(df_white.shape)
# Out:
# (1599, 12)
# (4898, 12)

# %%
df_red.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %% [markdown]
# # Mục mới

# %%
X_r = df_red[['volatile acidity','citric acid','residual sugar','chlorides']]
Y_r = df_red['quality']


x_tr_r, x_te_r = train_test_split(X_r,test_size=0.1,random_state=110)
y_tr_r , y_te_r = train_test_split(Y_r,test_size=0.1,random_state=110)
y_train1, y_test1 = train_test_split(df_white,test_size=0.1,random_state=100)

# %% [markdown]
# RED

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_tr_r,y_tr_r)
y_predicsion = regressor.predict(x_te_r)
y_predicsion = np.round(y_predicsion)

# %%
from scipy.sparse.linalg.isolve.minres import sqrt
from sklearn.metrics import mean_squared_error
RMSE = sqrt(mean_squared_error(y_te_r,y_predicsion))
print(RMSE)
# Out:
# 0.7373940601876312
